# %% [markdown]
# # Hierarchical  Clustering (HC)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# * En uzun distance olan yere threshold value atılır.Threshold value kaç çizgiyi kesiyor ise o kadar cluster olmalıdır.
